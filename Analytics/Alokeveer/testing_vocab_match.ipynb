# %%
# custom imports
import os
import sys

# import module 
import requests 
import pandas as pd 
from bs4 import BeautifulSoup 
import matplotlib.pyplot as plt 
from collections import defaultdict
import numpy as np

# %%
# natural language processing: n-gram ranking
import re
import unicodedata
import nltk
from nltk.corpus import stopwords

# %%
# pandas display settings
pd.options.display.max_columns = None
pd.options.display.max_rows = None
pd.options.display.width = None

# %%
# read and store all keywords in lowercase
stopwords_path = os.path.abspath(os.path.join(os.path.abspath("testing_vocab_match.ipynb"), "../../../Read_Files", "stopwords_cleaned.txt"))
with open(stopwords_path) as file:
    stopwords = [line.strip().lower() for line in file]

# %%
def extract_words_from_text(text):

    words = [w for w in text.split(' ')]
    return words

# %%
def extract_vocabulary():
    curr_path = os.path.abspath("testing_vocab_match_glamour_magazine.ipynb")
    df_path = os.path.abspath(os.path.join(curr_path, "../../..", "Read_Files/fashion_vocabulary.csv"))
    df = pd.read_csv(df_path)

    vocabulary_list = [v.lower() for v in df['Specifications']]

    return vocabulary_list

# %%
def extract_nouns(vocabulary_list):
    nouns = []
    for v in vocabulary_list:
        last_word = [w for w in v.split(' ')][-1]
        nouns.append(last_word)
    return nouns

# %%
# getting page content
html_response = requests.get("https://www.vogue.co.uk/fashion/gallery/spring-summer-2022-fashion-trends")
html_text = html_response.text
soup = BeautifulSoup(html_text, "lxml")

# %%
# function to cleanup text
def clean_text(text):
    """
    Function to clean up the passed text.\n
    All words are lemmatized afte encoding and basic regex parsing is performed.\n
    \n
    Parameters:
    text - Text to be worked with
    """

    # text cleaning
    text = (unicodedata.normalize('NFKD', text).encode('ascii', 'ignore').decode('utf-8', 'ignore').lower())
    words = re.sub(r'[^\w\s]', '', text).split()

    # word list
    return [word for word in words if word not in stopwords]

# %%
# various sources of text
para_texts = [element.text.strip() for element in soup.find_all("p")]
for p in range(len(para_texts)):
    if para_texts[p] == "":
        continue
    if para_texts[p][-1] != '.':
        para_texts[p] += '. '

header_texts = [element.text.strip() for element in soup.find_all(["h1", "h2", "h3", "h4", "h5", "h6"])]
for p in range(len(header_texts)):
    if header_texts[p] == "":
        continue
    if header_texts[p][-1] != '.':
        header_texts[p] += '. '

span_texts = [element.text.strip() for element in soup.find_all("span")]
for p in range(len(span_texts)):
    if span_texts[p] == "":
        continue
    if span_texts[p][-1] != '.':
        span_texts[p] += '. '

all_texts = para_texts + header_texts + span_texts
all_texts_string = ""
for v in all_texts:
    all_texts_string += v

all_texts_string = all_texts_string.lower()

print(all_texts_string)
# Out:
# follow us. by ellie pithers. “is not the most erotic portion of the body where the garment gapes?” posited french theorist roland barthes. one can only imagine how roland would react to the acres of flesh on show this past september, as dictated by the dominant spring/summer 2022 fashion trend. to put it in terms that cardi b would appreciate, when it comes to the new season, fashion is feeling all “macaroni in a pot”. short, sheer and second-skin takes on sexy are back.it’s been a while. sure, we’ve had underwear-as-outerwear renditions in recent seasons, with the odd pair of stripper heels making an unsolicited appearance. but, after a hot-vax summer during which young people threw their insecurities to the wind, embracing a daring vein of body positivity that had previously seemed like well-merchandised marketing spiel, designers found new ways to interpret sex.frequently, the results were see-through. young guns nensi dojaka and supriya lele have made this hedonistic approach their calling card, and their sheer, body-wrapping designs made headlines in london. occasionally, in paris, things got x-rated. ludovic de saint sernin, the young designer with a small but devoted following, showed a collection made up of tiny strips of leather braided together. it was sponsored by pornhub; a collaboration with the porn site is due in early 2022.read more: autumn/winter 2021 fashion trends. the big boys were feeling sexy, too. donatella versace can always be relied upon to inject some wiggle into fashion’s walk, and for spring she embraced thigh-slits, midriffs, chainmail and latex. ditto gucci, whose transparent lace mini dresses, latex bustiers, fishnets-and-suspender-belts and sex-toy accessories explored the “nuances of sensuality” in a blockbuster show in la. “seduction, stripped down” was the title of prada’s collection and, true to form, it poked fun at conventional interpretations of allure, exploring corsetry in itchy schoolmarmish wool and offsetting micro hemlines with demure kitten-heels. “we thought of words like elegant – but this feels so old-fashioned,” prada said in the show notes. sexy it is.it should be noted that fashion is finally wising up to the fact that sexy comes in all shapes, skin tones and sizes. about time! models precious lee, alva claire, paloma elsesser and yumi nu were among the most in-demand models for spring, bringing some much-needed body diversity to the runways. meanwhile indigenous model quannah chasinghorse made a splash in her debut season, walking for everyone from chanel to prabal gurung and gucci.by alice cary. a sense of loosening up permeated the collections, even when sex (or size) wasn’t on the brain. at chanel, the models even smiled, twirling for the cameras like ’90s supers and showing off micro hemlines. across the board, colour comes in juicy shots – unless it’s wiped completely, in favour of head-to-toe white. trains and capes, ripe for making an entrance (or, more accurately, an exit) proliferate with an urgency not seen since the mullet hems of the 2010s. the y2k revival continues apace. and say hello to the biker jacket, that once ubiquitous model-off-duty staple that suddenly feels right again.on that note, you may well have heard that covid killed fashion trends once and for all. and you would be partly right: spring/summer 2022 was a chaotic, creative mix of idiosyncratic takes on what the post-pandemic world wants right now. nowhere was this frenetic energy more evident than at louis vuitton, where nicolas ghesquière imagined “the figure of a vampire who travels through the ages, adapting to dress codes of the era.” think 18th-century pannier dresses with their hems chopped to reveal red satin superhero-style boots; cape-tuxedo hybrids paired with indigo jeans; gold-braid embellished waistcoats with short cargo skirts and floor-sweeping morticia addams capes.but there is a consensus on certain big ideas. trends are dead, long live trends. here, the 10 biggest spring/summe ...

# %%
vocabulary = extract_vocabulary()
print(vocabulary)
nouns = extract_nouns(vocabulary)
print(nouns)
# words = extract_words_from_text(all_texts_string)
# print(words)
words = clean_text(all_texts_string)
print(words)
# Out:
# ['three quarter length sleeve', 'unlined bottom', 'lined top', 'fit and flare', 'deep v neck', 'off the shoulder', 'peter pan collar', 'recycled cotton blends', 'organic cotton blends', 'recycled polyester blends', 'paper bag waist', 'contrast faux fur', 'black and white', 'blue and white', 'red and white', 'all over print', 'pop art print', 'roll up sleeve', 'non removable padding', 'soft & lightweight', '3 piece set', '2 piece set', 'track shorts', 'biker shorts', 'women tops', 'biker shorts', 'wide leg', 'flare leg', 'straight leg', 'cargo pants', 'track shorts', 'a line', 'mom fit', 'boyfriend fit', 'basic tops', 'pea coat', 'zip up', 'half placket', 'wide strap', 'push up', 'trench coat', 'faux fur', 'round neck', 'scoop neck', 'stand collar', 'spaghetti strap', 'one shoulder', 'v neck', 'high neck', 'baseball collar', 'square neck', 'asymmetrical neck', 'keyhole neckline', 'tie neck', 'cold shoulder', 'cowl neck', 'funnel neck', 'shawl collar', 'boat neck', 'sailor collar', 'mandarin collar', 'cotton blends', 'pu leather', 'wool-like fabric', 'recycle polyester', 'recycled polyester', 'lenzing™ viscose', 'faux fur', 'bamboo fiber', 'guipure lace', 'tencel™ modal', 'recycled cotton', 'acetic acid', 'tencel™ lyocell', 'coral fleece', 'mulberry silk', 'embroidery mesh', 'knee length', 'regular fit', 'slim fit', 'single breasted', 'single button', 'double breasted', 'half placket', 'fake pockets', 'button front', 'contrast lace', 'tiered layer', 'tie front', 'ruffle hem', 'lace up', 'pom pom', 'cut out', 'lettuce trim', 'contrast mesh', 'tie back', 'contrast binding', 'contrast sequin', 'raw hem', 'grommet eyelet', 'double button', 'split thigh', 'ruched bust', 'criss cross', 'contrast collar', 'high low', 'eyelet embroidery', 'fake drawstring', 'raw wash', "cat's whiskers", 'big bow', 'fake pockets', 'exaggerated ruffle', 'side stripe', 'fake buttons', 'ruffle neck', 'bow front', 'bow back', 'coffee brown', 'navy blue', 'dusty pink', 'baby pink', 'dusty blue', 'light grey', 'mustard yellow', 'olive green', 'army green', 'dark grey', 'dark green', 'chocolate brown', 'mocha brown', 'royal blue', 'mint green', 'burnt orange', 'lime green', 'hot pink', 'rust brown', 'cadet blue', 'dusty purple', 'baby blue', 'medium wash', 'dark wash', 'light wash', 'coral pink', 'rose red', 'teal blue', 'lilac purple', 'rusty rose', 'mint blue', 'coral orange', 'violet purple', 'red violet', 'mauve purple', 'watermelon pink', 'tie dye', 'polka dot', 'ditsy floral', 'snakeskin print', 'zebra stripe', 'scarf print', 'chain print', 'rainbow stripe', 'random print', 'landscape print', 'fish scales', 'long sleeve', 'half sleeve', 'short sleeve', 'cap sleeve', 'extra-long sleeve', 'slight stretch', 'high stretch', 'medium stretch', 'zipper fly', 'elastic waist', 'drawstring waist', 'button fly', 'high waist', 'drop waist', '100% polyurethane', 'drop shoulder', 'regular sleeve', 'bishop sleeve', 'butterfly sleeve', 'puff sleeve', 'batwing sleeve', 'raglan sleeve', 'flounce sleeve', 'leg-of-mutton sleeve', 'split sleeve', 'layered sleeve', 'cloak sleeve', 'petal sleeve', 'kimono sleeve', 'no padding', 'maximum comfort', '100% natural', 'sweatpants', 'leggings', 'pants', 'skirt', 'shorts', 'sweatshirt', 'jackets', 'tee', 'camisole', 'tunic', 'blouse', 'bandeau', 'regular', 'cape', 'waistcoat', 'blazer', 'regular', 'skinny', 'tapered/carrot', 'tailored', 'culottes', 'bodycon', 'pleated', 'straight', 'slit', 'layered/tiered', 'pencil', 'flared', 'pinafore', 'mermaid', 'asymmetrical', 'shirt', 'fitted', 'cami', 'tunic', 'smock', 'other', 'overall', 'unitard', 'tube', 'tank', 'tee', 'bermuda', 'wrap', 'top', 'peplum', 'bootcut', 'baggy', 'curvy', 'cape', 'sweatshirt', 'cardigan', 'coat', 'pullovers', 'shorts', 'pants', 'skirt', 'poncho', 'teddy', 'overcoat', 'vest', 'bomber', 'biker', 'windbreaker', 'puffer', 'parka', 'quilted', 'dress', 'halter', 'stirrup', 'harem/genie', 'jogger', 'jegging', 'kaftan', 'sheath', 'hooded', 'collar', 'straps', 'strapless',  ...
# ['sleeve', 'bottom', 'top', 'flare', 'neck', 'shoulder', 'collar', 'blends', 'blends', 'blends', 'waist', 'fur', 'white', 'white', 'white', 'print', 'print', 'sleeve', 'padding', 'lightweight', 'set', 'set', 'shorts', 'shorts', 'tops', 'shorts', 'leg', 'leg', 'leg', 'pants', 'shorts', 'line', 'fit', 'fit', 'tops', 'coat', 'up', 'placket', 'strap', 'up', 'coat', 'fur', 'neck', 'neck', 'collar', 'strap', 'shoulder', 'neck', 'neck', 'collar', 'neck', 'neck', 'neckline', 'neck', 'shoulder', 'neck', 'neck', 'collar', 'neck', 'collar', 'collar', 'blends', 'leather', 'fabric', 'polyester', 'polyester', 'viscose', 'fur', 'fiber', 'lace', 'modal', 'cotton', 'acid', 'lyocell', 'fleece', 'silk', 'mesh', 'length', 'fit', 'fit', 'breasted', 'button', 'breasted', 'placket', 'pockets', 'front', 'lace', 'layer', 'front', 'hem', 'up', 'pom', 'out', 'trim', 'mesh', 'back', 'binding', 'sequin', 'hem', 'eyelet', 'button', 'thigh', 'bust', 'cross', 'collar', 'low', 'embroidery', 'drawstring', 'wash', 'whiskers', 'bow', 'pockets', 'ruffle', 'stripe', 'buttons', 'neck', 'front', 'back', 'brown', 'blue', 'pink', 'pink', 'blue', 'grey', 'yellow', 'green', 'green', 'grey', 'green', 'brown', 'brown', 'blue', 'green', 'orange', 'green', 'pink', 'brown', 'blue', 'purple', 'blue', 'wash', 'wash', 'wash', 'pink', 'red', 'blue', 'purple', 'rose', 'blue', 'orange', 'purple', 'violet', 'purple', 'pink', 'dye', 'dot', 'floral', 'print', 'stripe', 'print', 'print', 'stripe', 'print', 'print', 'scales', 'sleeve', 'sleeve', 'sleeve', 'sleeve', 'sleeve', 'stretch', 'stretch', 'stretch', 'fly', 'waist', 'waist', 'fly', 'waist', 'waist', 'polyurethane', 'shoulder', 'sleeve', 'sleeve', 'sleeve', 'sleeve', 'sleeve', 'sleeve', 'sleeve', 'sleeve', 'sleeve', 'sleeve', 'sleeve', 'sleeve', 'sleeve', 'padding', 'comfort', 'natural', 'sweatpants', 'leggings', 'pants', 'skirt', 'shorts', 'sweatshirt', 'jackets', 'tee', 'camisole', 'tunic', 'blouse', 'bandeau', 'regular', 'cape', 'waistcoat', 'blazer', 'regular', 'skinny', 'tapered/carrot', 'tailored', 'culottes', 'bodycon', 'pleated', 'straight', 'slit', 'layered/tiered', 'pencil', 'flared', 'pinafore', 'mermaid', 'asymmetrical', 'shirt', 'fitted', 'cami', 'tunic', 'smock', 'other', 'overall', 'unitard', 'tube', 'tank', 'tee', 'bermuda', 'wrap', 'top', 'peplum', 'bootcut', 'baggy', 'curvy', 'cape', 'sweatshirt', 'cardigan', 'coat', 'pullovers', 'shorts', 'pants', 'skirt', 'poncho', 'teddy', 'overcoat', 'vest', 'bomber', 'biker', 'windbreaker', 'puffer', 'parka', 'quilted', 'dress', 'halter', 'stirrup', 'harem/genie', 'jogger', 'jegging', 'kaftan', 'sheath', 'hooded', 'collar', 'straps', 'strapless', 'lapel', 'halter', 'sweetheart', 'polo', 'notched', 'waterfall', 'polyester', 'chiffon', 'mesh', 'nylon', 'crochet', 'metallic', 'viscose', 'lace', 'cotton', 'rayon', 'velvet', 'glitter', 'sequins', 'corduroy', 'flannel', 'tweed', 'satin', 'suede', 'shearling', 'polyamide', 'schiffy', 'denim', 'silk', 'fleece', 'acrylic', 'acetate', 'elastane', 'modal', 'spandex', 'lycra', 'mohair', 'linen', 'woolen', 'organza', 'tencel', 'lyocell', 'ramie', 'cupro', 'cuprammonium', 'organic\xa0cotton', 'cashmere', 'wool', 'crop', 'regular', 'long', 'cropped', 'short', 'capris', 'mini', 'midi', 'maxi', 'asymmetrical', 'slit', 'pencil', 'straight', 'pleated', 'flared', 'flounce', 'mermaid', 'layered/tiered', 'wrap', 'skinny', 'loose', 'oversized', 'zipper', 'placket', 'pullovers', 'no', 'yes', 'knot', 'sheer', 'belted', 'embroidery', 'fringe', 'asymmetrical', 'drawstring', 'ruffle', 'scallop', 'split', 'pocket', 'rib-knit', 'ripped', 'ruched', 'rhinestone', 'zipper', 'button', 'chain', 'tape', 'wrap', 'ring', 'patched', 'shirred', 'frill', 'pleated', 'plicated', 'twist', 'backless', 'pearls', 'tassel', 'washed', 'flakes', 'beaded', 'studded', 'bow', 'draped', 'appliques', 'corset', 'padded', 'ribbon', 'feather', 'popover', 'braid', 'white', 'black', 'multicolor', 'gold', 'beige', 'redwood', 'green', 'apricot', 'pink', 'khaki', 'grey', 'champagne', ' ...
# ['follow', 'ellie', 'pithers', 'erotic', 'portion', 'body', 'garment', 'gapes', 'posited', 'french', 'theorist', 'roland', 'barthes', 'imagine', 'roland', 'react', 'acres', 'flesh', 'september', 'dictated', 'dominant', 'springsummer', '2022', 'fashion', 'trend', 'terms', 'cardi', 'season', 'fashion', 'feeling', 'macaroni', 'pot', 'short', 'sheer', 'secondskin', 'takes', 'sexy', 'backits', 'underwearasouterwear', 'renditions', 'seasons', 'odd', 'pair', 'stripper', 'heels', 'unsolicited', 'appearance', 'hotvax', 'summer', 'people', 'threw', 'insecurities', 'wind', 'embracing', 'daring', 'vein', 'body', 'positivity', 'wellmerchandised', 'marketing', 'spiel', 'designers', 'interpret', 'sexfrequently', 'seethrough', 'guns', 'nensi', 'dojaka', 'supriya', 'lele', 'hedonistic', 'approach', 'calling', 'card', 'sheer', 'bodywrapping', 'designs', 'headlines', 'london', 'occasionally', 'paris', 'xrated', 'ludovic', 'saint', 'sernin', 'designer', 'devoted', 'collection', 'tiny', 'strips', 'leather', 'braided', 'sponsored', 'pornhub', 'collaboration', 'porn', '2022read', 'autumnwinter', '2021', 'fashion', 'trends', 'boys', 'feeling', 'sexy', 'donatella', 'versace', 'relied', 'inject', 'wiggle', 'fashions', 'walk', 'spring', 'embraced', 'thighslits', 'midriffs', 'chainmail', 'latex', 'ditto', 'gucci', 'transparent', 'lace', 'mini', 'dresses', 'latex', 'bustiers', 'fishnetsandsuspenderbelts', 'sextoy', 'accessories', 'explored', 'nuances', 'sensuality', 'blockbuster', 'seduction', 'stripped', 'title', 'pradas', 'collection', 'true', 'form', 'poked', 'fun', 'conventional', 'interpretations', 'allure', 'exploring', 'corsetry', 'itchy', 'schoolmarmish', 'wool', 'offsetting', 'micro', 'hemlines', 'demure', 'kittenheels', 'elegant', 'feels', 'oldfashioned', 'prada', 'notes', 'sexy', 'isit', 'fashion', 'finally', 'wising', 'sexy', 'shapes', 'skin', 'tones', 'sizes', 'time', 'models', 'precious', 'lee', 'alva', 'claire', 'paloma', 'elsesser', 'yumi', 'indemand', 'models', 'spring', 'bringing', 'muchneeded', 'body', 'diversity', 'runways', 'indigenous', 'model', 'quannah', 'chasinghorse', 'splash', 'debut', 'season', 'walking', 'chanel', 'prabal', 'gurung', 'gucciby', 'alice', 'cary', 'sense', 'loosening', 'permeated', 'collections', 'sex', 'size', 'brain', 'chanel', 'models', 'smiled', 'twirling', 'cameras', '90s', 'supers', 'micro', 'hemlines', 'board', 'colour', 'juicy', 'shots', 'wiped', 'completely', 'favour', 'headtotoe', 'white', 'trains', 'capes', 'ripe', 'entrance', 'accurately', 'exit', 'proliferate', 'urgency', 'mullet', 'hems', '2010s', 'y2k', 'revival', 'continues', 'apace', 'biker', 'jacket', 'ubiquitous', 'modeloffduty', 'staple', 'suddenly', 'feels', 'againon', 'note', 'heard', 'covid', 'killed', 'fashion', 'trends', 'partly', 'springsummer', '2022', 'chaotic', 'creative', 'mix', 'idiosyncratic', 'takes', 'postpandemic', 'frenetic', 'energy', 'evident', 'louis', 'vuitton', 'nicolas', 'ghesquiere', 'imagined', 'figure', 'vampire', 'travels', 'ages', 'adapting', 'dress', 'codes', 'era', '18thcentury', 'pannier', 'dresses', 'hems', 'chopped', 'reveal', 'red', 'satin', 'superherostyle', 'boots', 'capetuxedo', 'hybrids', 'paired', 'indigo', 'jeans', 'goldbraid', 'embellished', 'waistcoats', 'short', 'cargo', 'skirts', 'floorsweeping', 'morticia', 'addams', 'capesbut', 'consensus', 'ideas', 'trends', 'dead', 'live', 'trends', '10', 'biggest', 'springsummer', '2022', 'fashion', 'trends', 'aboutjust', 'hemlines', 'miuccia', 'prada', 'miu', 'miu', 'pair', 'dressmaking', 'shears', 'skirt', 'worn', 'hips', 'cut', 'strip', 'covers', 'chuddies', 'underpants', 'international', 'readers', 'miu', 'mius', 'minis', 'racy', 'plenty', 'dolce', 'gabbana', 'versace', 'bottega', 'veneta', 'chanel', 'emporio', 'armani', 'details', 'dares', 'censure', 'reply', 'miuccias', 'gnomic', 'postshow', 'comment', 'strange', 'strange', 'biker', 'jacket', 'wild', 'buckle', 'lads', 'acne', 'studios', 'supriya', 'lele', 'miu', 'miu', 'biker', 'decidedly', '90s', 'mood', ' ...

# %%
def sort_dict_by_value(d, reverse = False):
  return dict(sorted(d.items(), key = lambda x: x[1], reverse = reverse))

# %%
prefix_dict = defaultdict(dict)
suffix_dict = defaultdict(dict)

for noun in nouns:
    for i in range(len(words)):
        if words[i].startswith(noun) == True:
            if i-1 >= 0:
                if words[i-1] in prefix_dict[words[i]].keys():
                    prefix_dict[words[i]][words[i-1]] += 1
                else:
                    prefix_dict[words[i]][words[i-1]] = 1
            if i+1 < len(words):
                if words[i+1] in suffix_dict[words[i]].keys():
                    suffix_dict[words[i]][words[i+1]] += 1
                else:
                    suffix_dict[words[i]][words[i+1]] = 1

for k, v in prefix_dict.items():
    print(k)
    print(sort_dict_by_value(v, True))
    print()

for k, v in suffix_dict.items():
    print(k)
    print(sort_dict_by_value(v, True))
    print()
# Out:
# tops
# {'goingout': 4, 'pastcrop': 4}
#
# shoulders
# {'puff': 4}
#
# waistcoats
# {'embellished': 6}
#
# white
# {'headtotoe': 8, 'colgate': 4, 'crisp': 4, 'updates': 4}
#
# set
# {'staple': 2}
#
# pants
# {'cotton': 3, 'lowrise': 3, 'cargo': 3}
#
# lines
# {'libertine': 1, 'armani': 1, '74183': 1}
#
# fit
# {'oversized': 4}
#
# fits
# {'sinuous': 4}
#
# coat
# {'feathered': 3}
#
# updates
# {'valentino': 3}
#
# strap
# {'single': 2}
#
# leather
# {'strips': 1, 'funky': 1}
#
# lace
# {'transparent': 3}
#
# cottons
# {'white': 2}
#
# cotton
# {'pair': 2}
#
# mesh
# {'sparkling': 3}
#
# hemlines
# {'micro': 4, 'aboutjust': 2}
#
# hems
# {'mullet': 2, 'dresses': 2}
#
# outre
# {'torch': 1}
#
# backits
# {'sexy': 2}
#
# sequins
# {'town': 2}
#
# thighslits
# {'embraced': 1}
#
# bustiers
# {'latex': 1}
#
# lowrise
# {'draping': 1, 'etro': 1}
#
# stripes
# {'selfassured': 3, 'fringed': 3}
#
# brown
# {'chocolate': 5}
#
# browne
# {'thom': 10}
#
# blue
# {'cerulean': 8}
#
# pink
# {'enjoyment': 6}
#
# red
# {'reveal': 2, 'guccis': 2}
#
# reduced
# {'pho': 2}
#
# flying
# {'flutes': 2}
#
# comfortable
# {'invest': 1}
#
# comfortdriven
# {'premise': 1}
#
# skirts
# {'cargo': 2}
#
# skirt
# {'shears': 2, 'pleated': 2}
#
# capes
# {'trains': 2}
#
# capetuxedo
# {'boots': 2}
#
# capesbut
# {'addams': 2}
#
# caped
# {'red': 2}
#
# blazer
# {'structured': 1}
#
# skinny
# {'chains': 2}
#
# pleated
# {'ease': 3}
#
# straightforward
# {'looked': 2}
#
# mermaids
# {'girlslowwaisted': 2}
#
# baggy
# {'levis': 1}
#
# biker
# {'apace': 1, 'strange': 1, 'miu': 1}
#
# dresses
# {'mini': 2, 'pannier': 1}
#
# dress
# {'adapting': 1, 'mini': 1, 'key': 1, 'fluid': 1, 'forgo': 1}
#
# dressmaking
# {'pair': 1}
#
# lapelfree
# {'slimfit': 1}
#
# lapels
# {'sharp': 1}
#
# satin
# {'red': 1, 'prada': 1}
#
# denim
# {'mixed': 1, 'deepblue': 1}
#
# wool
# {'schoolmarmish': 1}
#
# crop
# {'flesh': 1}
#
# cropped
# {'tulle': 2}
#
# short
# {'pot': 1, 'waistcoats': 1, 'super': 1}
#
# mini
# {'lace': 1, 'caped': 1, 'andersons': 1}
#
# minis
# {'mius': 1}
#
# minimalists
# {'marniheres': 1}
#
# maximilian
# {'reactions': 1, 'mcqueen': 1, '59183': 1}
#
# maximum
# {'creating': 1}
#
# loosening
# {'sense': 1}
#
# oversized
# {'prada': 1}
#
# notes
# {'prada': 6, 'succinctly': 6}
#
# note
# {'againon': 6, 'exit': 6}
#
# no21
# {'westwood': 6, '129183': 6}
#
# sheer
# {'short': 1, 'card': 1, 'trendsuper': 1, 'tailoring': 1}
#
# fringed
# {'stripes': 1}
#
# fringe
# {'coat': 1}
#
# chainmail
# {'midriffs': 1, 'sequins': 1}
#
# chains
# {'body': 1}
#
# corsetry
# {'exploring': 1}
#
# feathered
# {'guccis': 1}
#
# braided
# {'leather': 1}
#
# goldbraid
# {'jeans': 1}
#
# champagne
# {'send': 1}
#
# elegant
# {'kittenheels': 1}
#
# sexy
# {'takes': 1, 'feeling': 1, 'notes': 1, 'wising': 1, 'outre': 1, 'fendi': 1, '115183': 1}
#
# figure
# {'imagined': 1}
#
# butterfly
# {'fairiessexy': 1}
#
# cardi
# {'terms': 1}
#
# card
# {'calling': 1}
#
# cary
# {'alice': 3}
#
# cargo
# {'short': 1, 'stomachbared': 1}
#
# carrying
# {'designers': 1}
#
# carolina
# {'strada': 1, 'ize': 1, '61183': 1, '78183': 1}
#
# summer
# {'hotvax': 1}
#
# springsummer
# {'dominant': 1, 'partly': 1, 'biggest': 1, 'fresh': 1, 'key': 1}
#
# spring
# {'walk': 1, 'models': 1, 'shape': 1, '2000s': 1}
#
# springs
# {'luck': 1}
#
# allure
# {'interpretations': 1}
#
# fall
# {'generation': 1}
#
# warm
# {'bohemian': 1}
#
# tops
# {'paired': 4, 'butterflies': 4}
#
# shoulders
# {'smothered': 4}
#
# waistcoats
# {'short': 6}
#
# white
# {'trains': 4, 'worn': 4, 'cottons': 4, 'trouser': 4, 'bohemian': 4}
#
# set
# {'dominatecome': 2}
#
# pants
# {'deep': 3, 'body': 3, 'popped': 3}
#
# lines
# {'marniheres': 1, 'duro': 1, '75183': 1}
#
# fit
# {'multiple': 4}
#
# fits
# {'crisp': 4}
#
# coat
# {'fringe': 3}
#
# updates
# {'white': 3}
#
# strap
# {'throat': 2}
#
# leather
# {'braided': 1, 'mixed': 1}
#
# lace
# {'mini': 3}
#
# cottons
# {'hermes': 2}
#
# cotton
# {'pants': 2}
#
# mesh
# {'crystals': 3}
#
# hemlines
# {'demure': 2, 'board': 2, 'miuccia': 2}
#
# hems
# {'2010s': 2, 'chopped': 2}
#
# outre
# {'sexy': 1}
#
# backits
# {'underwearasouterwear': 2}
#
# sequins
# {'chainmail': 2}
#
# thighslits
# {'midriffs': 1}
#
# bustiers
# {'fishnetsandsuspenderbelts': 1}
#
# lowrise
# {'pants': 1, 'stomachbared': 1}
#
# stripes
# {'fringed': 3, 'yup': 3}
#
# brown
# {'raspberry': 5}
#
# browne
# {'versace': 5, '178183': 5}
#
# blue
# {'mingled': 8}
#
# pink
# {'prada': 6}
#
# red
# {'satin': 2, 'caped': 2}
#
# reduced
# {'edited': 2}
#
# flying
# {'hours': 2}
#
# comfortable
# {'pair': 1}
#
# comfortdriven
# {'forgo': 1}
#
# skirts
# {'floorsweeping': 2}
#
# skirt
# {'worn': 2, 'luck': 2}
#
# capes
# {'ripe': 2}
#
# capetuxedo
# {'hybrids': 2}
#
# capesbut
# {'consensus': 2}
#
# caped
# {'mini': 2}
#
# blazer
# {'fluid': 1}
#
# skinny
# {'completely': 2}
#
# pleated
# {'skirt': 3}
#
# straightforward
# {'tonal': 2}
#
# mermaids
# {'newseason': 2}
#
# baggy
# {'jeans': 1}
#
# biker
# {'jacket': 2, 'decidedly': 1}
#
# dresses
# {'latex': 1, 'hems': 1, 'louis': 1}
#
# dress
# {'codes': 1, 'wafts': 1, 'shape': 1, 'altuzarra': 1, 'suggested': 1}
#
# dressmaking
# {'shears': 1}
#
# lapelfree
# {'motorcycle': 1}
#
# lapels
# {'feminine': 1}
#
# satin
# {'superherostyle': 1, 'tail': 1}
#
# denim
# {'sharp': 1, 'guccis': 1}
#
# wool
# {'offsetting': 1}
#
# crop
# {'designers': 1}
#
# cropped
# {'smoking': 2}
#
# short
# {'sheer': 1, 'cargo': 1, 'key': 1}
#
# mini
# {'dresses': 2, 'dress': 1}
#
# minis
# {'racy': 1}
#
# minimalists
# {'shock': 1}
#
# maximilian
# {'spikes': 1, 'collina': 1, '60183': 1}
#
# maximum
# {'drama': 1}
#
# loosening
# {'permeated': 1}
#
# oversized
# {'fit': 1}
#
# notes
# {'sexy': 6, 'lot': 6}
#
# note
# {'heard': 6, 'advocating': 6}
#
# no21
# {'david': 6, '130183': 6}
#
# sheer
# {'secondskin': 1, 'bodywrapping': 1, 'super': 1, 'tights': 1}
#
# fringed
# {'stripes': 1}
#
# fringe
# {'feels': 1}
#
# chainmail
# {'latex': 1, 'sparkling': 1}
#
# chains
# {'skinny': 1}
#
# corsetry
# {'itchy': 1}
#
# feathered
# {'coat': 1}
#
# braided
# {'sponsored': 1}
#
# goldbraid
# {'embellished': 1}
#
# champagne
# {'flutes': 1}
#
# elegant
# {'feels': 1}
#
# sexy
# {'backits': 1, 'donatella': 1, 'isit': 1, 'shapes': 1, 'led': 1, 'nensi': 1, '116183': 1}
#
# figure
# {'vampire': 1}
#
# butterfly
# {'girlslowwaisted': 1}
#
# cardi
# {'season': 1}
#
# card
# {'sheer': 1}
#
# cary
# {'sense': 1, 'alice': 1, '1183': 1}
#
# cargo
# {'skirts': 1, 'pants': 1}
#
# carrying
# {'torch': 1}
#
# carolina
# {'herrera': 4}
#
# summer
# {'people': 1}
#
# springsummer
# {'2022': 5}
#
# spring
# {'embraced': 1, 'bringing': 1, 'fashions': 1, 'blumarine': 1}
#
# springs
# {'fashion': 1}
#
# allure
# {'exploring': 1}
#
# fall
# {'single': 1}
#
# warm
# {'cosy': 1}

# %%
all_keywords = list(set(prefix_dict.keys()).union(set(suffix_dict.keys())))
all_keywords.sort() 
print(all_keywords)
df = pd.DataFrame(columns=['Prefix3', 'Prefix2', 'Prefix1', 'Keyword', 'Suffix1', 'Suffix2', 'Suffix3'])

for keyword in all_keywords:
    current_row = ["-", "-", "-", keyword, "-", "-", "-"]
    j = 2
    for (k, v) in sort_dict_by_value(prefix_dict[keyword]).items():
        if j == -1:
            break
        current_row[j] = f"({k}, {v})"
        j -= 1    

    j = 4
    for (k, v) in sort_dict_by_value(suffix_dict[keyword]).items():
        if j == 7:
            break
        current_row[j] = f"({k}, {v})"
        j += 1     

    df.loc[len(df.index)] = current_row
# Out:
# ['allure', 'backits', 'baggy', 'biker', 'blazer', 'blue', 'braided', 'brown', 'browne', 'bustiers', 'butterfly', 'caped', 'capes', 'capesbut', 'capetuxedo', 'card', 'cardi', 'cargo', 'carolina', 'carrying', 'cary', 'chainmail', 'chains', 'champagne', 'coat', 'comfortable', 'comfortdriven', 'corsetry', 'cotton', 'cottons', 'crop', 'cropped', 'denim', 'dress', 'dresses', 'dressmaking', 'elegant', 'fall', 'feathered', 'figure', 'fit', 'fits', 'flying', 'fringe', 'fringed', 'goldbraid', 'hemlines', 'hems', 'lace', 'lapelfree', 'lapels', 'leather', 'lines', 'loosening', 'lowrise', 'maximilian', 'maximum', 'mermaids', 'mesh', 'mini', 'minimalists', 'minis', 'no21', 'note', 'notes', 'outre', 'oversized', 'pants', 'pink', 'pleated', 'red', 'reduced', 'satin', 'sequins', 'set', 'sexy', 'sheer', 'short', 'shoulders', 'skinny', 'skirt', 'skirts', 'spring', 'springs', 'springsummer', 'straightforward', 'strap', 'stripes', 'summer', 'thighslits', 'tops', 'updates', 'waistcoats', 'warm', 'white', 'wool']

# %%
# print summary
# set output path
curr_path = os.path.abspath("testing_vocab_match.ipynb")
print(curr_path)
output_path = os.path.abspath(os.path.join(curr_path, "../", "Outputs/Glamour_Magazine_vocab_match_prefix_suffix.txt"))

# write to file
original_stdout = sys.stdout
with open(output_path, "w") as f:
    sys.stdout = f

    print('Fashion vocabulary with top 3 prefices and suffices')

    print(df.to_string())

    # print('WORDS with top 3 prefices and seuffices')

    # for(k, v) in prefix_dict.items():
    #     print("Word:", k)
    #     print()
    #     print("Top 3 prefices:")
    #     j = 1
    #     for (k1, v1) in sort_dict_by_value(v).items():
    #         if j > 3:
    #             break
    #         else:
    #             print(k1, v1)
    #     print()
    #     print("Top 3 suffices:")
    #     j = 1
    #     for (k1, v1) in sort_dict_by_value(suffix_dict[k]).items():
    #         if j > 3:
    #             break
    #         else:
    #             print(k1, v1)
    #     print()

    # reset stdout
    sys.stdout = original_stdout
# Out:
# e:\Projects\Curience-Work\Analytics\Alokeveer\testing_vocab_match.ipynb

# %%
pd.__version__
# Out:
# '1.3.5'
